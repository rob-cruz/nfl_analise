# %%
#!pip install html5lib

# %%
url = 'https://www.espn.com/nfl/team/roster/_/name/dal/dallas-cowboys'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.135 Safari/537.36'}

# %%
import requests
import json
from bs4 import BeautifulSoup
import os
import time
import urllib.request

# %%
espn = 'https://www.espn.com/nfl/team/roster/_/name/ari/arizona-cardinals'

# %%
#Consulte o site e retorne o html para a variável 'page'
page = urllib.request.urlopen(espn)

# %%
soup = BeautifulSoup(page, 'html5lib')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <!-- ESPNFITT | 98dc7fcc4991 | 7435558 | 2b164a97 | www.espn.com | Sun, 10 Dec 2023 23:24:16 GMT -->
#   <script async="" src="https://dcf.espn.com/TWDC-DTCI/prod/Bootstrap.js">
#   </script>
#   <script data-nr-pct="1" data-nr-type="legacy">
#    (() => {function gc(n){n=document.cookie.match("(^|;) ?"+n+"=([^;]*)(;|$)");return n?n[2]:null}function sc(n){document.cookie=n}function smpl(n){n/=100;return!!n&&Math.random()<=n}var _nr=!1,_nrCookie=gc("_nr");null!==_nrCookie?"1"===_nrCookie&&(_nr=!0):smpl(1)?(_nr=!0,sc("_nr=1; path=/")):(_nr=!1,sc("_nr=0; path=/"));_nr && (() => {;window.NREUM||(NREUM={});NREUM.init={distributed_tracing:{enabled:true},privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]}};;NREUM.info = {"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","sa":1,"licenseKey":"d1734eda45","applicationID":"350640159"};__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(31),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(32),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError";if(!c.disabled){var l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(14),t(13),"addEventListener"in window&&t(7),c.xhrWrappable&&t(15),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){U++,L=g.hash,this[u]=y.now()}function o(){U--,g.hash!==L&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(11),b=t(12),E=t(9),R=t(7),O=t(14),T=t(8),S=t(15),P=t(10),M=t("ee"),C=M.get("tracer"),N=t(23);t(17),y.features.spa=!0;var L,U=0;M.on(u,r),b.on(p,r),P.on(p,r),M.on(d,o),b.on(l,o),P.on(l,o),M.buffer([u,d,"xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),S.buffer([u,"new-xhr","send-xhr"+s]),T.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),C.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,m+s),a(T,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,N(!0)),w[v]("load",i,N(!0)),w[v]("popstate",function(){i(0,U>1)},N(!0))}},{}],5:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(v,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function o(t){if(s(v,[window.performance.getEntriesByType(w)]),window.performance["c"+p])try{window.performance[h](m,o,!1)}catch(t){}else try{window.performance[h]("webkit"+m,o,!1)}catch(t){}}function i(t){}if(window.performance&&window.performance.timing&&window.perfor ...
#   </script>
#   <title data-react-helmet="true">
#    Arizona Cardinals 2023 NFL Roster - ESPN
#   </title>
#   <meta content="Explore the 2023 Arizona Cardinals NFL roster on ESPN. Includes full details on offense, defense and special teams." data-react-helmet="true" name="description"/>
#   <meta content="116656161708917" data-react-helmet="true" property="fb:app_id"/>
#   <meta content="ESPN" data-react-helmet="true" property="og:site_name"/>
#   <meta content="https://www.espn.com/nfl/team/roster/_/name/ari/arizona-cardinals" data-react-helmet="true" property="og:url"/>
#   <meta content="Arizona Cardinals 2023 NFL Roster - ESPN" data-react-helmet="true" property="og:title"/>
#   <meta content="Explore the 2023 Arizona Cardinals NFL roster on ESPN. Includes full details on offense, defense and special teams." data-react-helmet="true" property="og:description"/>
#   <meta content="https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/ari.png" data-react-helmet="true" property="og:image"/>
#   <meta content="500" data-react-helmet="true" property="og:image:width"/>
#   <meta content="500" data-react-helmet="true" property="og:image:height"/>
#   <meta content="website" data-react-helmet="true" property="og:type"/>
#   <meta content="espn" data-react-helmet="true" name="twitter:site"/>
#   <meta content="https://www.espn.com/nfl/team/roster/_/name/ari/arizona-cardinals" data-react-helmet="true" name="twitter:url"/>
#   <meta content="Arizona Cardinals 2023 NFL Roster - ESPN" data-react-helmet="true" name="twitter:title"/>
#   <meta content="Explore the 2023 Arizona Cardinals NFL roster on ESPN. Includes full details on offense, defense and special teams." data-react-helmet="true" name="twitter:description"/>
#   <meta content="summary" data-react-helmet="true" name="twitter:card"/>
#   <meta content="https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/ari.png" data-react-helmet="true" name="twitter:image"/>
#   <meta content="ESPN" data-react-helmet="true" name="twitter:app:name:iphone"/>
#   <meta content="317469184" data-react-helmet="true" name="twitter:app:id:iphone"/>
#   <meta content="ESPN" data-react-helmet="true" name="twitter:app:name:googleplay"/>
#   <meta content="com.espn.score_center" data-react-helmet="true" name="twitter:app:id:googleplay"/>
#   <meta content="Arizona Cardinals 2023 NFL Roster - ESPN" data-react-helmet="true" name="title"/>
#   <meta content="website" data-react-helmet="true" name="medium"/>
#   <meta content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="IE=edge" http-equiv="x-ua-compatible"/>
#   <meta content="en_US" property="og:locale"/>
#   <link href="//cdn1.espn.net" rel="preconnect"/>
#   <link crossorigin="" href="https://tredir.espn.com" rel="preconnect"/>
#   <link crossorigin="" href="https://cdn.registerdisney.go.com" rel="preconnect"/>
#   <link crossorigin="" href="https://fan.api.espn.com" rel="preconnect"/>
#   <link crossorigin="" href="https://cdn.espn.com" rel="preconnect"/>
#   <link crossorigin="" href="https://a.espncdn.com" rel="preconnect"/>
#   <link crossorigin="" href="https://site.web.api.espn.com" rel="preconnect"/>
#   <link color="#990000" href="https://a.espncdn.com/prod/assets/icons/E.svg" rel="mask-icon" sizes="any"/>
#   <link href="https://a.espncdn.com/favicon.ico" rel="shortcut icon"/>
#   <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" rel="apple-touch-icon"/>
#   <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-57x57.png" rel="apple-touch-icon-precomposed"/>
#   <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <link href="https://a.espncdn.com/wireless/mw5/r1/images/bookmark-icons-v2/espn-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <link data-react-helmet="true" href="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/css/2957-794c0249.css" rel="stylesheet"/>
#   <link data-react-helmet="true" href="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/css/espnfitt-8bc97e39.css" rel="stylesheet"/>
#   <link data-react-helmet="true" href="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/css/fusion-b959162e.css" rel="stylesheet"/>
#   <link data-react-helmet="true" href="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/css/6629-5d51bfb0.css" rel="stylesheet"/>
#   <link data-react-helmet="true" href="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/css/1992-af03ed87.css" rel="stylesheet"/>
#   <link data-react-helmet="true" href="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/css/team.roster-ef3b3dcc.css" rel="stylesheet"/>
#   <link data-react-helmet="true" href="https://www.espn.com/nfl/team/roster/_/name/ari/arizona-cardinals" rel="canonical"/>
#   <link data-react-helmet="true" href="https://www.espn.com/nfl/team/roster/_/name/ari/arizona-cardinals" hreflang="en-us" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.com.br/nfl/time/elenco/_/nome/ari/arizona-cardinals" hreflang="pt-br" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.in/nfl/team/roster/_/name/ari/arizona-cardinals" hreflang="en-in" rel="alternate"/>
#   <link data-react-helmet="true" href="https://africa.espn.com/nfl/team/roster/_/name/ari/arizona-cardinals" hreflang="en-za" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.com.ve/futbol-americano/nfl/equipo/plantel/_/nombre/ari/arizona-cardinals" hreflang="es-ve" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.cl/futbol-americano/nfl/equipo/plantel/_/nombre/ari/arizona-cardinals" hreflang="es-cl" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.com.mx/futbol-americano/nfl/equipo/plantel/_/nombre/ari/arizona-cardinals" hreflang="es-mx" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.com.co/futbol-americano/nfl/equipo/plantel/_/nombre/ari/arizona-cardinals" hreflang="es-co" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.com.pe/futbol-americano/nfl/equipo/plantel/_/nombre/ari/arizona-cardinals" hreflang="es-pe" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.com.ar/futbol-americano/nfl/equipo/plantel/_/nombre/ari/arizona-cardinals" hreflang="es-ar" rel="alternate"/>
#   <link data-react-helmet="true" href="https://espndeportes.espn.com/futbol-americano/nfl/equipo/plantel/_/nombre/ari/arizona-cardinals" hreflang="es-us" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.ph/nfl/team/roster/_/name/ari/arizona-cardinals" hreflang="en-ph" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.co.uk/nfl/team/roster/_/name/ari/arizona-cardinals" hreflang="en-gb" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.com.sg/nfl/team/roster/_/name/ari/arizona-cardinals" hreflang="en-sg" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.com.gt/futbol-americano/nfl/equipo/plantel/_/nombre/ari/arizona-cardinals" hreflang="es-gt" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.com.uy/futbol-americano/nfl/equipo/plantel/_/nombre/ari/arizona-cardinals" hreflang="es-uy" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.com.do/futbol-americano/nfl/equipo/plantel/_/nombre/ari/arizona-cardinals" hreflang="es-do" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.com.ec/futbol-americano/nfl/equipo/plantel/_/nombre/ari/arizona-cardinals" hreflang="es-ec" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.com.pa/futbol-americano/nfl/equipo/plantel/_/nombre/ari/arizona-cardinals" hreflang="es-pa" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.co.cr/futbol-americano/nfl/equipo/plantel/_/nombre/ari/arizona-cardinals" hreflang="es-cr" rel="alternate"/>
#   <link data-react-helmet="true" href="https://www.espn.nl/nfl/team/selectie/_/naam/ari/arizona-cardinals" hreflang="nl-nl" rel="alternate"/>
#   <script defer="" src="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/runtime-e14f9897.js">
#   </script>
#   <script defer="" src="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/2957-b3c73a38.js">
#   </script>
#   <script defer="" src="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/3242-b7aebb2d.js">
#   </script>
#   <script defer="" src="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/9264-ae343d28.js">
#   </script>
#   <script defer="" src="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/4857-aed28a60.js">
#   </script>
#   <script defer="" src="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/736-f86544f5.js">
#   </script>
#   <script defer="" src="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/6629-5fedba03.js">
#   </script>
#   <script defer="" src="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/6746-1ec689a2.js">
#   </script>
#   <script defer="" src="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/6756-e0d16c99.js">
#   </script>
#   <script defer="" src="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/2327-e6787a27.js">
#   </script>
#   <link as="script" href="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/_manifest.js" rel="prefetch"/>
#   <link as="script" href="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/espn-en-9b286014.js" rel="prefetch"/>
#   <link as="script" href="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/espnfitt-07d5f3e3.js" rel="prefetch"/>
#   <link as="script" href="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/team.roster-1a93a713.js" rel="prefetch"/>
#   <style id="fittLoadingStyle" type="text/css">
#    .page-container,
#    .Nav__Primary__Menu,
#    .Nav__Secondary__Menu,
#     .NavSecondary--GamePackage,
#    .SoccerPerformers--gamepackage,
#    .Gamestrip,
#    .Ad:before {
#        opacity:                    0;
#    }
#   </style>
#   <noscript>
#    <style type="text/css">
#     div.HeaderScoreboardContainer, div.Ad, div.sponsored-content { display: none !important; }
#                 .page-container,
#                 .Nav__Primary .Nav__Primary__Menu .Nav__Primary__Menu__Item a,
#                 .Nav__Primary .Nav__Primary__Menu .Nav__Primary__Menu__Item .Nav__Primary__Menu__Link,
#                 .Nav__Secondary .Nav__Secondary__Menu .Nav__Secondary__Menu__Title .Nav__Secondary__Menu__Link,
#                 .Nav__Secondary .Nav__Secondary__Menu .Nav__Secondary__Menu__Item .Nav__Secondary__Menu__Link {
#                     opacity: 1;
#                 }
#    </style>
#   </noscript>
#   <script async="" src="https://a.espncdn.com/prod/scripts/analytics/ESPN_at_v2.rs.min.js">
#   </script>
#  </head>
#  <body>
#   <img alt="" height="99999" src="data:image/svg+xml;base64,..." style="pointer-events: none; position: absolute; top: 0; left: 0; width: 99%; height: 99%; max-width: 99%; max-height: 99%;" width="99999"/>
#   <div id="espnfitt">
#    <div id="DataWrapper">
#     <div id="fitt-analytics">
#      <div class="bp-mobileMDPlus bp-mobileLGPlus bp-tabletPlus bp-desktopPlus bp-desktopLGPlus" data-fitt-page-type="team">
#       <div class="HeaderScoreboardWrapper">
#        <div class="HeaderScoreboardContainer HeaderScoreboardContainer--loading">
#         <section aria-label="HeaderScoreboard" class="HeaderScoreboard HeaderScoreboard--empty">
#          <button class="HiddenSkip" data-skip="content">
#           Skip to main content
#          </button>
#          <button class="HiddenSkip" data-skip="nav">
#           Skip to navigation
#          </button>
#          <div class="HeaderScoreboard__Wrapper">
#           <div class="HeaderScoreboard__Carousel">
#            <div class="HeaderScoreboard__Carousel__Nav HeaderScoreboard__Carousel__Nav--prev is-disabled">
#             <svg aria-hidden="true" class="icon__svg" viewBox="0 0 24 24">
#              <use xlink:href="#icon__caret__left">
#              </use>
#             </svg>
#            </div>
#            <div class="HeaderScoreboard__Carousel__Wrapper">
#             <div style="transform:translateX(0px);transition:0.7s ease">
#              <div class="HeaderScoreboard__Events">
#               <div class="HeaderScoreboard__SportSection">
#                <div class="ScoreCell ScoreCell--md ScoreCell--noLinks" role="group">
#                 <a class="ScoreCell__Link">
#                  <div class="ScoreCell__Link__Event__Detail">
#                   <div class="ScoreCell__CompetitorDetails">
#                    <ul class="ScoreCell__Competitors">
#                    </ul>
#                   </div>
#                  </div>
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="HeaderScoreboard__Carousel__Nav HeaderScoreboard__Carousel__Nav--next is-disabled">
#             <svg aria-hidden="true" class="icon__svg" viewBox="0 0 24 24">
#              <use xlink:href="#icon__caret__right">
#              </use>
#             </svg>
#            </div>
#           </div>
#          </div>
#         </section>
#        </div>
#       </div>
#       <header class="db Site__Header__Wrapper sticky top-0">
#        <div class="Site__Header db left-0 top-0 sticky w-100 bg-clr-gray-02 Site__Header--espn">
#         <nav aria-label="Global Navigation" class="Nav__Primary center flex justify-between items-center">
#          <div class="Nav__Primary__Branding__Logo">
#           <div class="Nav__Primary__Branding__Wrapper">
#            <a aria-label="ESPN Home Page" class="AnchorLink Nav__Primary__Branding Nav__Primary__Branding--espn" href="/" tabindex="0">
#             ESPN
#            </a>
#           </div>
#          </div>
#          <ul class="Nav__Primary__Menu flex Nav__Primary__Menu--left w-100">
#           <div>
#            <li class="Nav__Primary__Menu__Item flex items-center relative Nav__Primary__Menu__Item--active n7 Nav__AccessibleMenuItem_Wrapper">
#             <a aria-label="ESPN NFL Home Page" aria-selected="true" class="AnchorLink Button--unstyled Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/nfl/" id="nav-link-undefined" tabindex="0">
#              <span class="Nav__Text">
#               NFL
#              </span>
#             </a>
#             <button aria-expanded="false" aria-haspopup="true" aria-label="NFL" class="Button--unstyled Nav__Primary__Menu__Toggle" tabindex="0">
#              <svg aria-hidden="true" class="Nav__SubmenuIndicatorIcon icon__svg fill-clr-white icon_svg--dark icon__svg" role="img" viewBox="0 0 24 24">
#               <title id="undefined-submenu">
#                NFL
#               </title>
#               <use xlink:href="#icon__caret__down">
#               </use>
#              </svg>
#             </button>
#            </li>
#           </div>
#           <div>
#            <li class="Nav__Primary__Menu__Item flex items-center relative n7 Nav__AccessibleMenuItem_Wrapper">
#             <a aria-label="ESPN NCAAF Home Page" aria-selected="false" class="AnchorLink Button--unstyled Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/college-football/" id="nav-link-undefined" tabindex="0">
#              <span class="Nav__Text">
#               NCAAF
#              </span>
#             </a>
#             <button aria-expanded="false" aria-haspopup="true" aria-label="NCAAF" class="Button--unstyled Nav__Primary__Menu__Toggle" tabindex="0">
#              <svg aria-hidden="true" class="Nav__SubmenuIndicatorIcon icon__svg fill-clr-white icon_svg--dark icon__svg" role="img" viewBox="0 0 24 24">
#               <title id="undefined-submenu">
#                NCAAF
#               </title>
#               <use xlink:href="#icon__caret__down">
#               </use>
#              </svg>
#             </button>
#            </li>
#           </div>
#           <div>
#            <li class="Nav__Primary__Menu__Item flex items-center relative n7 Nav__AccessibleMenuItem_Wrapper">
#             <a aria-label="ESPN NBA Home Page" aria-selected="false" class="AnchorLink Button--unstyled Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/nba/" id="nav-link-undefined" tabindex="0">
#              <span class="Nav__Text">
#               NBA
#              </span>
#             </a>
#             <button aria-expanded="false" aria-haspopup="true" aria-label="NBA" class="Button--unstyled Nav__Primary__Menu__Toggle" tabindex="0">
#              <svg aria-hidden="true" class="Nav__SubmenuIndicatorIcon icon__svg fill-clr-white icon_svg--dark icon__svg" role="img" viewBox="0 0 24 24">
#               <title id="undefined-submenu">
#                NBA
#               </title>
#               <use xlink:href="#icon__caret__down">
#               </use>
#              </svg>
#             </button>
#            </li>
#           </div>
#           <div>
#            <li class="Nav__Primary__Menu__Item flex items-center relative n7 Nav__AccessibleMenuItem_Wrapper">
#             <a aria-label="ESPN NHL Home Page" aria-selected="false" class="AnchorLink Button--unstyled Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/nhl/" id="nav-link-undefined" tabindex="0">
#              <span class="Nav__Text">
#               NHL
#              </span>
#             </a>
#             <button aria-expanded="false" aria-haspopup="true" aria-label="NHL" class="Button--unstyled Nav__Primary__Menu__Toggle" tabindex="0">
#              <svg aria-hidden="true" class="Nav__SubmenuIndicatorIcon icon__svg fill-clr-white icon_svg--dark icon__svg" role="img" viewBox="0 0 24 24">
#               <title id="undefined-submenu">
#                NHL
#               </title>
#               <use xlink:href="#icon__caret__down">
#               </use>
#              </svg>
#             </button>
#            </li>
#           </div>
#           <div>
#            <li class="Nav__Primary__Menu__Item flex items-center relative n7 Nav__AccessibleMenuItem_Wrapper">
#             <a aria-label="ESPN MLB Home Page" aria-selected="false" class="AnchorLink Button--unstyled Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/mlb/" id="nav-link-undefined" tabindex="0">
#              <span class="Nav__Text">
#               MLB
#              </span>
#             </a>
#             <button aria-expanded="false" aria-haspopup="true" aria-label="MLB" class="Button--unstyled Nav__Primary__Menu__Toggle" tabindex="0">
#              <svg aria-hidden="true" class="Nav__SubmenuIndicatorIcon icon__svg fill-clr-white icon_svg--dark icon__svg" role="img" viewBox="0 0 24 24">
#               <title id="undefined-submenu">
#                MLB
#               </title>
#               <use xlink:href="#icon__caret__down">
#               </use>
#              </svg>
#             </button>
#            </li>
#           </div>
#           <div>
#            <li class="Nav__Primary__Menu__Item flex items-center relative n7 Nav__AccessibleMenuItem_Wrapper">
#             <a aria-label="ESPN Soccer Home Page" aria-selected="false" class="AnchorLink Button--unstyled Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/soccer/" id="nav-link-undefined" tabindex="0">
#              <span class="Nav__Text">
#               Soccer
#              </span>
#             </a>
#             <button aria-expanded="false" aria-haspopup="true" aria-label="Soccer" class="Button--unstyled Nav__Primary__Menu__Toggle" tabindex="0">
#              <svg aria-hidden="true" class="Nav__SubmenuIndicatorIcon icon__svg fill-clr-white icon_svg--dark icon__svg" role="img" viewBox="0 0 24 24">
#               <title id="undefined-submenu">
#                Soccer
#               </title>
#               <use xlink:href="#icon__caret__down">
#               </use>
#              </svg>
#             </button>
#            </li>
#           </div>
#           <div>
#            <li class="Nav__Primary__Menu__Item flex items-center relative n7 Nav__AccessibleMenuItem_Wrapper">
#             <a aria-label="ESPN More Sports Home Page" aria-selected="false" class="AnchorLink Button--unstyled Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com" id="nav-link-undefined" tabindex="0">
#              <svg aria-hidden="false" aria-labelledby="navMoreSportsLabel" class="Nav__Primary__Icon__MoreSports icon__svg" focusable="false" role="img" viewBox="0 0 24 24">
#               <title id="navMoreSportsLabel">
#                More Sports
#               </title>
#               <use xlink:href="#icon__more__dots">
#               </use>
#              </svg>
#             </a>
#             <button aria-expanded="false" aria-haspopup="true" aria-label="More Sports" class="Button--unstyled Nav__Primary__Menu__Toggle" tabindex="0">
#              <svg aria-hidden="true" class="Nav__SubmenuIndicatorIcon icon__svg fill-clr-white icon_svg--dark icon__svg" role="img" viewBox="0 0 24 24">
#               <title id="undefined-submenu">
#                More Sports
#               </title>
#               <use xlink:href="#icon__caret__down">
#               </use>
#              </svg>
#             </button>
#            </li>
#           </div>
#          </ul>
#          <ul class="Nav__Primary__Menu flex Nav__Primary__Menu--right flex-none">
#           <div>
#            <li class="Nav__Primary__Menu__Item flex items-center relative n7 Nav__AccessibleMenuItem_Wrapper">
#             <a aria-selected="false" class="AnchorLink Button--unstyled Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="https://www.espn.com/espnplus/?om-navmethod=topnav" id="nav-link-undefined" tabindex="0">
#              <img alt="ESPN+" class="Image Nav__Primary__Icon__ESPNPlus" data-mptype="image" src="..."/>
#             </a>
#             <button aria-expanded="false" aria-haspopup="true" aria-label="ESPN Plus" class="Button--unstyled Nav__Primary__Menu__Toggle" tabindex="0">
#              <svg aria-hidden="true" class="Nav__SubmenuIndicatorIcon icon__svg fill-clr-white icon_svg--dark icon__svg" role="img" viewBox="0 0 24 24">
#               <title id="undefined-submenu">
#                ESPN Plus
#               </title>
#               <use xlink:href="#icon__caret__down">
#               </use>
#              </svg>
#             </button>
#            </li>
#           </div>
#           <div>
#            <li class="Nav__Primary__Menu__Item flex items-center relative n7 Nav__AccessibleMenuItem_Wrapper">
#             <a aria-selected="false" class="AnchorLink Button--unstyled Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com/watch/" id="nav-link-undefined" tabindex="0">
#              <span class="Nav__Text">
#               Watch
#              </span>
#             </a>
#             <button aria-expanded="false" aria-haspopup="true" aria-label="Watch" class="Button--unstyled Nav__Primary__Menu__Toggle" tabindex="0">
#              <svg aria-hidden="true" class="Nav__SubmenuIndicatorIcon icon__svg fill-clr-white icon_svg--dark icon__svg" role="img" viewBox="0 0 24 24">
#               <title id="undefined-submenu">
#                Watch
#               </title>
#               <use xlink:href="#icon__caret__down">
#               </use>
#              </svg>
#             </button>
#            </li>
#           </div>
#           <div>
#            <li class="Nav__Primary__Menu__Item flex items-center relative n7 Nav__AccessibleMenuItem_Wrapper">
#             <a aria-selected="false" class="AnchorLink Button--unstyled Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="https://espnbet.app.link/V424mquT4Eb?$3p=a_espn" id="nav-link-undefined" tabindex="0">
#              <img alt="ESPN BET" class="Image Nav__Primary__Icon__ESPNBet" data-mptype="image" src="..."/>
#             </a>
#             <button aria-expanded="false" aria-haspopup="true" aria-label="ESPN BET" class="Button--unstyled Nav__Primary__Menu__Toggle" tabindex="0">
#              <svg aria-hidden="true" class="Nav__SubmenuIndicatorIcon icon__svg fill-clr-white icon_svg--dark icon__svg" role="img" viewBox="0 0 24 24">
#               <title id="undefined-submenu">
#                ESPN BET
#               </title>
#               <use xlink:href="#icon__caret__down">
#               </use>
#              </svg>
#             </button>
#            </li>
#           </div>
#           <div>
#            <li class="Nav__Primary__Menu__Item flex items-center relative n7 Nav__AccessibleMenuItem_Wrapper">
#             <a aria-selected="false" class="AnchorLink Button--unstyled Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="/fantasy/" id="nav-link-undefined" tabindex="0">
#              <span class="Nav__Text">
#               Fantasy
#              </span>
#             </a>
#             <button aria-expanded="false" aria-haspopup="true" aria-label="Fantasy" class="Button--unstyled Nav__Primary__Menu__Toggle" tabindex="0">
#              <svg aria-hidden="true" class="Nav__SubmenuIndicatorIcon icon__svg fill-clr-white icon_svg--dark icon__svg" role="img" viewBox="0 0 24 24">
#               <title id="undefined-submenu">
#                Fantasy
#               </title>
#               <use xlink:href="#icon__caret__down">
#               </use>
#              </svg>
#             </button>
#            </li>
#           </div>
#           <div>
#            <li class="Nav__Primary__Menu__Item flex items-center relative n7 Nav__AccessibleMenuItem_Wrapper">
#             <a aria-selected="false" class="AnchorLink Button--unstyled Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com" id="nav-link-undefined" tabindex="0">
#              <svg aria-hidden="false" aria-labelledby="navMoreESPNLabel" class="Nav__Primary__Icon__More icon__svg" focusable="false" role="img" viewBox="0 0 24 24">
#               <title id="navMoreESPNLabel">
#                More ESPN
#               </title>
#               <use xlink:href="#icon__more__grid">
#               </use>
#              </svg>
#             </a>
#             <button aria-expanded="false" aria-haspopup="true" aria-label="More ESPN" class="Button--unstyled Nav__Primary__Menu__Toggle" tabindex="0">
#              <svg aria-hidden="true" class="Nav__SubmenuIndicatorIcon icon__svg fill-clr-white icon_svg--dark icon__svg" role="img" viewBox="0 0 24 24">
#               <title id="undefined-submenu">
#                More ESPN
#               </title>
#               <use xlink:href="#icon__caret__down">
#               </use>
#              </svg>
#             </button>
#            </li>
#           </div>
#          </ul>
#          <ul class="Nav__Primary__Menu flex Nav__Primary__Menu--right flex-none">
#           <li class="Nav__Primary__Menu__Item Nav__Search flex-none relative">
#            <div class="Nav__Search__Toggle">
#             <svg aria-expanded="false" aria-hidden="false" aria-labelledby="navSearchLabel" class="icon__svg" role="button" tabindex="0" viewBox="0 0 24 24">
#              <title id="navSearchLabel">
#               Search
#              </title>
#              <use xlink:href="#icon__search">
#              </use>
#             </svg>
#            </div>
#           </li>
#          </ul>
#         </nav>
#        </div>
#       </header>
#       <div id="fittBGContainer">
#        <div id="fittBGContainerInner">
#         <div id="fittBGContainerInside">
#          <div data-box-type="fitt-adbox-wallpaper" id="fittBGAd">
#           <div class="Ad ad-slot" data-collapse-before-load="true" data-exclude-bp="s,m" data-slot-kvps="pos=wallpaper" data-slot-type="wallpaper">
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <main id="fittPageContainer" tabindex="-1">
#        <div data-box-type="fitt-adbox-exclusions">
#         <div class="Ad ad-slot" data-category-exclusion="true" data-slot-kvps="pos=exclusions" data-slot-type="exclusions">
#         </div>
#        </div>
#        <div class="StickyContainer" data-sticky-parent="true">
#         <div class="ResponsiveWrapper">
#          <div class="ClubhouseHeader w-100 overflow-hidden bb ph4 ClubhouseHeader--tabletPlus bg-clr-white brdr-clr-gray-10">
#           <div class="ClubhouseHeader__Container w-100 center flex items-center justify-between">
#            <div class="ClubhouseHeader__Main flex items-center pv3 justify-start">
#             <img alt="Cardinals" class="Image Logo Logo__xxl" data-mptype="image" src="..."/>
#             <div class="ClubhouseHeader__Main_Aside pl4 relative">
#              <h1 class="ClubhouseHeader__Name ttu flex items-start n2">
#               <span class="flex flex-wrap">
#                <span class="db pr3 nowrap">
#                 Arizona
#                </span>
#                <span class="db fw-bold">
#                 Cardinals
#                </span>
#               </span>
#              </h1>
#              <div class="ClubhouseHeader__TeamDetails flex items-center mt3">
#               <button class="Button Button--sm Button--alt ClubhouseHeader__Follow" tabindex="0">
#                Follow
#               </button>
#               <ul class="list flex ClubhouseHeader__Record n8 ml4">
#                <li>
#                 3-10
#                </li>
#                <li>
#                 4th in NFC West
#                </li>
#               </ul>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="" data-sticky="true">
#          <div class="ScrollSpy_container">
#           <span>
#           </span>
#          </div>
#          <nav aria-label="Secondary Navigation" class="Nav__Secondary bg-clr-white brdr-clr-gray-03">
#           <ul class="Nav__Secondary__Menu center flex items-center relative">
#            <li class="Nav__Secondary__Menu__Title flex-none n7 mr2 relative hideLogoUntilSticky">
#             <a class="AnchorLink Nav__Secondary__Menu__Link clr-gray-01 flex items-center pl3 pr4" href="/nfl/team/_/name/ari/arizona-cardinals" tabindex="0">
#              <img alt="" class="Image Logo Nav__Secondary__Menu__Logo mr2 Logo__md" data-mptype="image" src="..."/>
#              <span class="Nav__Text">
#              </span>
#             </a>
#            </li>
#            <div>
#             <li class="Nav__Secondary__Menu__Item flex items-center n7 relative n7 Nav__AccessibleMenuItem_Wrapper">
#              <a aria-selected="false" class="AnchorLink Button--unstyled Nav__Secondary__Menu__Link clr-gray-01 flex items-center ph3" data-track-linkid="team_sitenav_home" href="/nfl/team/_/name/ari/arizona-cardinals" id="nav-link-undefined" tabindex="0">
#               <span class="Nav__Text">
#                Home
#               </span>
#              </a>
#             </li>
#            </div>
#            <div>
#             <li class="Nav__Secondary__Menu__Item flex items-center n7 relative n7 Nav__AccessibleMenuItem_Wrapper">
#              <a aria-selected="false" class="AnchorLink Button--unstyled Nav__Secondary__Menu__Link clr-gray-01 flex items-center ph3" data-track-linkid="team_sitenav_stats" href="/nfl/team/stats/_/name/ari/arizona-cardinals" id="nav-link-undefined" tabindex="0">
#               <span class="Nav__Text">
#                Stats
#               </span>
#              </a>
#             </li>
#            </div>
#            <div>
#             <li class="Nav__Secondary__Menu__Item flex items-center n7 relative n7 Nav__AccessibleMenuItem_Wrapper">
#              <a aria-selected="false" class="AnchorLink Button--unstyled Nav__Secondary__Menu__Link clr-gray-01 flex items-center ph3" data-track-linkid="team_sitenav_schedule" href="/nfl/team/schedule/_/name/ari/arizona-cardinals" id="nav-link-undefined" tabindex="0">
#               <span class="Nav__Text">
#                Schedule
#               </span>
#              </a>
#             </li>
#            </div>
#            <div>
#             <li class="Nav__Secondary__Menu__Item flex items-center n7 relative Nav__Secondary__Menu__Item--active n7 Nav__AccessibleMenuItem_Wrapper">
#              <a aria-selected="true" class="AnchorLink Button--unstyled Nav__Secondary__Menu__Link clr-gray-01 flex items-center ph3" data-track-linkid="team_sitenav_roster" href="/nfl/team/roster/_/name/ari/arizona-cardinals" id="nav-link-undefined" tabindex="0">
#               <span class="Nav__Text">
#                Roster
#               </span>
#              </a>
#             </li>
#            </div>
#            <div>
#             <li class="Nav__Secondary__Menu__Item flex items-center n7 relative n7 Nav__AccessibleMenuItem_Wrapper">
#              <a aria-selected="false" class="AnchorLink Button--unstyled Nav__Secondary__Menu__Link clr-gray-01 flex items-center ph3" data-track-linkid="team_sitenav_depth chart" href="/nfl/team/depth/_/name/ari/arizona-cardinals" id="nav-link-undefined" tabindex="0">
#               <span class="Nav__Text">
#                Depth Chart
#               </span>
#              </a>
#             </li>
#            </div>
#            <div>
#             <li class="Nav__Secondary__Menu__Item flex items-center n7 relative n7 Nav__AccessibleMenuItem_Wrapper">
#              <a aria-selected="false" class="AnchorLink Button--unstyled Nav__Secondary__Menu__Link clr-gray-01 flex items-center ph3" data-track-linkid="team_sitenav_injuries" href="/nfl/team/injuries/_/name/ari/arizona-cardinals" id="nav-link-undefined" tabindex="0">
#               <span class="Nav__Text">
#                Injuries
#               </span>
#              </a>
#             </li>
#            </div>
#            <div>
#             <li class="Nav__Secondary__Menu__Item flex items-center n7 relative n7 Nav__AccessibleMenuItem_Wrapper">
#              <a aria-selected="false" class="AnchorLink Button--unstyled Nav__Secondary__Menu__Link clr-gray-01 flex items-center ph3" data-track-linkid="team_sitenav_transactions" href="/nfl/team/transactions/_/name/ari/arizona-cardinals" id="nav-link-undefined" tabindex="0">
#               <span class="Nav__Text">
#                Transactions
#               </span>
#              </a>
#             </li>
#            </div>
#            <div>
#             <li class="Nav__Secondary__Menu__Item flex items-center n7 relative n7 Nav__AccessibleMenuItem_Wrapper">
#              <a aria-selected="false" class="AnchorLink Button--unstyled Nav__Secondary__Menu__Link clr-gray-01 flex items-center ph3" data-track-linkid="team_sitenav_blog" href="/blog/arizona-cardinals" id="nav-link-undefined" tabindex="0">
#               <span class="Nav__Text">
#                Blog
#               </span>
#              </a>
#             </li>
#            </div>
#            <div>
#             <li class="Nav__Secondary__Menu__Item flex items-center n7 relative justify-between n7 Nav__AccessibleMenuItem_Wrapper">
#              <a aria-selected="false" class="AnchorLink Button--unstyled Nav__Secondary__Menu__Link clr-gray-01 flex items-center ph3" data-track-custom="yes" data-track-linkid="team_sitenav_tickets" data-track-nav_item="https://www.vividseats.com/nfl/arizona-cardinals-tickets.html?wsUser=717&amp;wsVar=us~nfl~team,nfl,desktop,en" href="https://www.vividseats.com/nfl/arizona-cardinals-tickets.html?wsUser=717&amp;wsVar=us~nfl~team,nfl,desktop,en" id="nav-link-undefined" rel="noopener" tabindex="0" target="_blank">
#               <span class="Nav__Text">
#                Tickets
#               </span>
#               <svg aria-hidden="false" aria-label="External Link" class="icon-external ml2 icon__svg" role="img" tabindex="-1" viewBox="0 0 24 24">
#                <title>
#                 External Link
#                </title>
#                <use xlink:href="#icon__external">
#                </use>
#               </svg>
#              </a>
#             </li>
#            </div>
#            <div>
#             <li class="Nav__Secondary__Menu__Item flex items-center n7 relative Nav__Secondary__Menu__Item--more n7 Nav__AccessibleMenuItem_Wrapper">
#              <a aria-selected="false" class="AnchorLink Button--unstyled Nav__Secondary__Menu__Link clr-gray-01 flex items-center ph3" data-track-linkid="team_sitenav_more" href="#" id="nav-link-undefined" tabindex="0">
#               <span class="Nav__Text">
#                More
#               </span>
#              </a>
#              <button aria-expanded="false" aria-haspopup="true" aria-label="More" class="Button--unstyled Nav__Primary__Menu__Toggle" tabindex="0">
#               <svg aria-hidden="true" class="Nav__SubmenuIndicatorIcon icon__svg icon__svg" role="img" viewBox="0 0 24 24">
#                <title id="undefined-submenu">
#                 More
#                </title>
#                <use xlink:href="#icon__caret__down">
#                </use>
#               </svg>
#              </button>
#             </li>
#            </div>
#           </ul>
#          </nav>
#         </div>
#         <div class="" data-sticky="true">
#          <div class="StickyContainer--gradient">
#          </div>
#         </div>
#         <div data-box-type="fitt-adbox-banner">
#          <div class="Ad Ad--banner ad-slot" data-slot-kvps="pos=banner" data-slot-type="banner">
#          </div>
#         </div>
#         <div class="page-container cf">
#          <div class="layout is-9-3">
#           <div aria-label="Standings Page" class="layout__column layout__column--1" role="main">
#            <section class="Card">
#             <div class="Wrapper Card__Content">
#              <section>
#               <div class="flex justify-between mt3 mb3-mb4 items-center">
#                <h1 class="headline headline__h1 dib">
#                 Arizona Cardinals Roster 2023
#                </h1>
#                <div class="dropdown dropdown--md h-100 pageHeading__team-stats-dropdown bp-mobile">
#                 <svg aria-hidden="true" class="dropdown__arrow icon__svg" viewBox="0 0 24 24">
#                  <use xlink:href="#icon__caret__down">
#                  </use>
#                 </svg>
#                 <select class="dropdown__select" name="1702250656612::6fbb0000::42fdcfeb:221b:d87b:39dc:5a4f4a016456" style="text-overflow:ellipsis;overflow:hidden;width:126px">
#                  <option class="dropdown__option" data-url="/nfl/team/roster" hidden="" value="Selected">
#                   More NFL Teams
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/atl/atlanta-falcons" value="1">
#                   Atlanta Falcons
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/bal/baltimore-ravens" value="33">
#                   Baltimore Ravens
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/buf/buffalo-bills" value="2">
#                   Buffalo Bills
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/car/carolina-panthers" value="29">
#                   Carolina Panthers
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/chi/chicago-bears" value="3">
#                   Chicago Bears
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/cin/cincinnati-bengals" value="4">
#                   Cincinnati Bengals
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/cle/cleveland-browns" value="5">
#                   Cleveland Browns
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/dal/dallas-cowboys" value="6">
#                   Dallas Cowboys
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/den/denver-broncos" value="7">
#                   Denver Broncos
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/det/detroit-lions" value="8">
#                   Detroit Lions
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/gb/green-bay-packers" value="9">
#                   Green Bay Packers
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/hou/houston-texans" value="34">
#                   Houston Texans
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/ind/indianapolis-colts" value="11">
#                   Indianapolis Colts
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/jax/jacksonville-jaguars" value="30">
#                   Jacksonville Jaguars
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/kc/kansas-city-chiefs" value="12">
#                   Kansas City Chiefs
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/lv/las-vegas-raiders" value="13">
#                   Las Vegas Raiders
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/lac/los-angeles-chargers" value="24">
#                   Los Angeles Chargers
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/lar/los-angeles-rams" value="14">
#                   Los Angeles Rams
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/mia/miami-dolphins" value="15">
#                   Miami Dolphins
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/min/minnesota-vikings" value="16">
#                   Minnesota Vikings
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/ne/new-england-patriots" value="17">
#                   New England Patriots
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/no/new-orleans-saints" value="18">
#                   New Orleans Saints
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/nyg/new-york-giants" value="19">
#                   New York Giants
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/nyj/new-york-jets" value="20">
#                   New York Jets
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/phi/philadelphia-eagles" value="21">
#                   Philadelphia Eagles
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/pit/pittsburgh-steelers" value="23">
#                   Pittsburgh Steelers
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/sf/san-francisco-49ers" value="25">
#                   San Francisco 49ers
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/sea/seattle-seahawks" value="26">
#                   Seattle Seahawks
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/tb/tampa-bay-buccaneers" value="27">
#                   Tampa Bay Buccaneers
#                  </option>
#                  <option class="dropdown__option" data-url="/nfl/team/roster/_/name/ten/tennessee-titans" value="10">
# ...
#                        <div class="inline" style="min-width:40px">
#                         33
#                        </div>
#                       </td>
#                       <td class="Table__TD">
#                        <div class="inline" style="min-width:50px">
#                         6' 5"
#                        </div>
#                       </td>
#                       <td class="Table__TD">
#                        <div class="inline" style="min-width:70px">
#                         232 lbs
#                        </div>
#                       </td>
#                       <td class="Table__TD">
#                        <div class="inline" style="min-width:50px">
#                         12
#                        </div>
#                       </td>
#                       <td class="Table__TD">
#                        <div class="inline" style="min-width:140px">
#                         San Diego State
#                        </div>
#                       </td>
#                      </tr>
#                     </tbody>
#                    </table>
#                   </div>
#                   <div class="Table__Shadow--right" style="opacity:0">
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div class="TableDetails pt4">
#                <p class="TableDetails__Paragraph">
#                 <span class="TableDetails__Headline">
#                  Coach
#                 </span>
#                 <!-- -->
#                 Jonathan Gannon
#                </p>
#               </div>
#              </section>
#             </div>
#            </section>
#            <div>
#             <div class="sponsored-content sl-horizontal">
#              <div class="sponsored-headlines relative sl-wrapper w-100 taboola">
#               <div id="roster-thumbnails-3x2-a">
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div aria-label="All NFL News" class="layout__column layout__column--2" role="complementary">
#            <aside>
#             <div data-box-type="fitt-adbox-incontentstrip">
#              <div class="Ad Ad--inContentStrip ad-slot" data-collapse-before-load="true" data-slot-kvps="pos=incontentstrip" data-slot-type="incontentstrip">
#              </div>
#             </div>
#             <div data-box-type="fitt-adbox-incontent">
#              <div class="Ad Ad--inContent ad-slot" data-slot-kvps="pos=incontent" data-slot-type="incontent">
#              </div>
#             </div>
#             <section class="Card News">
#              <header aria-label="NFL News" class="Card__Header News__Header">
#               <div class="Card__Header__Title__Wrapper">
#                <h3 class="Card__Header__Title Card__Header__Title--no-theme">
#                 NFL News
#                </h3>
#               </div>
#              </header>
#              <div class="Wrapper Card__Content">
#               <div class="ContentList" role="list">
#                <div class="ContentList__Item" role="listitem">
#                 <a class="AnchorLink News__Item external flex flex-row" href="/nfl/story/_/id/39086341/chargers-justin-herbert-leaves-game-finger-injury" name="&amp;lpos=toolkit" tabindex="0">
#                  <figure class="Image aspect-ratio--parent News__Item__Thumbnail overflow-hidden">
#                   <div class="RatioFrame aspect-ratio--1x1">
#                   </div>
#                   <div class="Image__Wrapper aspect-ratio--child">
#                    <img alt="Chargers' Justin Herbert leaves game with finger injury" class="" data-mptype="image" src="..."/>
#                   </div>
#                  </figure>
#                  <div class="News__Content__Container">
#                   <h2 aria-label="Chargers' Justin Herbert leaves game with finger injury" class="News__Item__Headline">
#                    Chargers' Justin Herbert leaves game with finger injury
#                   </h2>
#                   <div aria-label="Chargers quarterback Justin Herbert was sidelined late in the second quarter of Los Angeles' game against the Broncos on Sunday due to a finger injury." class="News__Item__Description">
#                    Chargers quarterback Justin Herbert was sidelined late in the second quarter of Los Angeles' game against the Broncos on Sunday due to a finger injury.
#                   </div>
#                   <ul class="MetaContent">
#                    <li class="MetaContent__Item MetaContent__Item__Timestamp">
#                     5m
#                    </li>
#                    <li class="MetaContent__Item MetaContent__Item__Author">
#                     Kris Rhim
#                    </li>
#                   </ul>
#                  </div>
#                 </a>
#                </div>
#                <div class="ContentList__Item" role="listitem">
#                 <a class="AnchorLink News__Item external flex flex-row" href="/video/clip/_/id/39086266" name="&amp;lpos=toolkit" tabindex="0">
#                  <figure class="Image aspect-ratio--parent News__Item__Thumbnail overflow-hidden">
#                   <div class="RatioFrame aspect-ratio--1x1">
#                   </div>
#                   <div class="Image__Wrapper aspect-ratio--child">
#                    <img alt="Devin Singletary or Dameon Pierce: Which Texans RB should fantasy mangers target?" class="" data-mptype="image" src="..."/>
#                   </div>
#                  </figure>
#                  <div class="News__Content__Container">
#                   <h2 aria-label="Devin Singletary or Dameon Pierce: Which Texans RB should fantasy mangers target?" class="News__Item__Headline">
#                    Devin Singletary or Dameon Pierce: Which Texans RB should fantasy mangers target?
#                   </h2>
#                   <div aria-label="Eric Karabell makes his case for fantasy managers starting Devin Singletary over Dameon Pierce." class="News__Item__Description">
#                    Eric Karabell makes his case for fantasy managers starting Devin Singletary over Dameon Pierce.
#                   </div>
#                   <ul class="MetaContent">
#                    <li class="MetaContent__Item MetaContent__Item__Timestamp">
#                     15m
#                    </li>
#                   </ul>
#                  </div>
#                 </a>
#                </div>
#                <div class="ContentList__Item" role="listitem">
#                 <a class="AnchorLink News__Item external flex flex-row" href="/nfl/story/_/id/39086134/vikings-justin-jefferson-suffers-chest-injury-vs-raiders-ruled-out" name="&amp;lpos=toolkit" tabindex="0">
#                  <figure class="Image aspect-ratio--parent News__Item__Thumbnail overflow-hidden">
#                   <div class="RatioFrame aspect-ratio--1x1">
#                   </div>
#                   <div class="Image__Wrapper aspect-ratio--child">
#                    <img alt="Vikings' Justin Jefferson suffers chest injury vs. Raiders, ruled out" class="" data-mptype="image" src="..."/>
#                   </div>
#                  </figure>
#                  <div class="News__Content__Container">
#                   <h2 aria-label="Vikings' Justin Jefferson suffers chest injury vs. Raiders, ruled out" class="News__Item__Headline">
#                    Vikings' Justin Jefferson suffers chest injury vs. Raiders, ruled out
#                   </h2>
#                   <div aria-label="Vikings receiver Justin Jefferson, who returned Sunday after a seven-game absence, suffered a chest injury in the second quarter and won't return vs. the Raiders." class="News__Item__Description">
#                    Vikings receiver Justin Jefferson, who returned Sunday after a seven-game absence, suffered a chest injury in the second quarter and won't return vs. the Raiders.
#                   </div>
#                   <ul class="MetaContent">
#                    <li class="MetaContent__Item MetaContent__Item__Timestamp">
#                     14m
#                    </li>
#                    <li class="MetaContent__Item MetaContent__Item__Author">
#                     Kevin Seifert
#                    </li>
#                   </ul>
#                  </div>
#                 </a>
#                </div>
#               </div>
#              </div>
#              <footer class="Card__Footer">
#               <a class="AnchorLink News__FooterLink external" href="/nfl/" tabindex="0">
#                All NFL News
#               </a>
#              </footer>
#             </section>
#            </aside>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="PageLayout page-container cf page-footer-container">
#         <div aria-label="Page Footer" class="PageLayout__Main" role="region">
#          <section class="Card PageFooter">
#           <div class="Wrapper Card__Content PageFooter__Card__Content">
#            <div class="PageFooter__Footer flex items-stretch">
#             <div class="PageFooter__Logo__Wrapper flex flex-none items-center">
#              <img alt="ESPN" class="Image PageFooter__Logo" data-mptype="image" src="..."/>
#             </div>
#             <section aria-label="Legal Footer Navigation" class="LegalFooter LegalFooter--default">
#              <div class="LegalFooter__Links overflow-hidden">
#               <ul class="LegalFooter__Links__List flex">
#                <li class="LegalFooter__Links__Item nowrap relative LegalFooter__Link--underline-hover">
#                 <a class="AnchorLink LegalFooter__Link LegalFooter__Link--underline-hover" href="https://disneytermsofuse.com/brazilian-portuguese/" tabindex="0">
#                  Termos de uso
#                 </a>
#                </li>
#                <li class="LegalFooter__Links__Item nowrap relative LegalFooter__Link--underline-hover">
#                 <a class="AnchorLink LegalFooter__Link LegalFooter__Link--underline-hover" href="https://privacy.thewaltdisneycompany.com/pt-br/" tabindex="0">
#                  Política de privacidade
#                 </a>
#                </li>
#                <li class="LegalFooter__Links__Item nowrap relative LegalFooter__Link--underline-hover">
#                 <a class="AnchorLink LegalFooter__Link LegalFooter__Link--underline-hover" href="http://preferences-mgr.truste.com/?type=espn&amp;affiliateId=148" tabindex="0">
#                  Anúncios baseados em interesses
#                 </a>
#                </li>
#                <li class="LegalFooter__Links__Item nowrap relative LegalFooter__Link--underline-hover">
#                 <a class="AnchorLink LegalFooter__Link LegalFooter__Link--underline-hover" href="https://privacy.thewaltdisneycompany.com/pt-br/nossa-politica-de-privacidade/protecao-de-dados-no-brasil/" tabindex="0">
#                  Proteção de Dados no Brasil
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="LegalFooter__Copyright">
#               © 2020 ESPN Internet Ventures. Todos os direitos reservados.
#              </div>
#             </section>
#            </div>
#           </div>
#          </section>
#         </div>
#        </div>
#       </main>
#       <div id="fittOverlayContainer">
#        <div data-box-type="fitt-adbox-overlay" id="fittOverlayContainerInner">
#         <div class="Ad ad-slot" data-out-of-page="true" data-slot-kvps="pos=outofpage" data-slot-type="overlay">
#         </div>
#        </div>
#       </div>
#       <div class="ResponsiveWrapper" data-wrapping="Lightbox">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    window['__CONFIG__']={"uid":"espnfitt","strictMode":false,"mode":"universal","logLevel":"info","logOutput":"json","tms":{"enabled":true,"env":"dev","tag":"https://nexus.ensighten.com/TWDC-DTCI/dev/Bootstrap.js","tagNS":"Boostrapper","emitEvent":"tms:ready","loadScript":false,"loadAsync":true},"allowMocks":true,"globalVar":"__espnfitt__","cdnPath":"//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client","buildHash":false,"http":{"timeout":{"client":5000}},"apiEnv":"production","envName":"prod","mockDataPort":1981,"host":"localhost","basename":"","toodles":{"enabled":true,"serviceName":"fitt","hostedZone":"espnsb.com","clusterName":"NodeCluster","apiHost":"https://edge.us-east-1.aws.hosted.espnsb.com"}};window['__espnfitt__']={"app":{"uid":"espnfitt","mode":"universal","apiEnv":"production","envName":"prod","cdnPath":"//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client","allowMocks":true,"mockDataPort":1981,"excludePageCSS":false,"assets":{"chunks":["//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/runtime-e14f9897.js","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/2957-b3c73a38.js","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/3242-b7aebb2d.js","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/9264-ae343d28.js","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/4857-aed28a60.js","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/736-f86544f5.js","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/6629-5fedba03.js","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/6746-1ec689a2.js","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/6756-e0d16c99.js","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/2327-e6787a27.js"],"entries":["//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/espn-en-9b286014.js","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/espnfitt-07d5f3e3.js","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/team.roster-1a93a713.js"],"css":["//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/css/2957-794c0249.css","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/css/espnfitt-8bc97e39.css","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/css/fusion-b959162e.css","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/css/6629-5d51bfb0.css","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/css/1992-af03ed87.css","//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/css/team.roster-ef3b3dcc.css"],"stylesheets":[]},"device":"desktop","modifier":"","edition":{"config":{},"translations":{}},"flags":{"ads":true,"athLnks":true,"nav":true,"hsb":true,"anltcs":true,"otbrn":true,"qaAPI":false,"sbAPI":false,"localAPI":false,"previewAPI":false,"gmStrp":true,"evtLnks":true,"exLnks":true,"rmLnscr":false,"rtCol":true,"srchOrg":"","tier3Nv":true,"tmLnks":true,"footer":true,"video":true},"tms":{"enabled":true,"env":"dev","tag":"https://dcf.espn.com/TWDC-DTCI/prod/Bootstrap.js","tagNS":"Boostrapper","emitEvent":"tms:ready","loadScript":false,"loadAsync":true,"cmpLoaded":false,"ready":false},"toodles":{},"frameAncestors":["'self'","asia.espn.com:*","asia.espnqa.com:*","*.espn.com:*","*.espnqa.com:*","*.espnsb.com:*","*.espnsb.com","*.espn.co.uk","*.espndeportes.espn.com","*.espn.com.br","*.espn.com.mx","*.espn.com.ve","*.espn.com.ar","*.espn.com.co","*.espnfc.com.au","*.espn.com.au","*.espn.in","*.espn.com.sg","*.espn.cl","*.espn.ph","*.espn.ph:*","*.espn.com.pe","*.espn.com.gt","*.espn.com.do","*.espn.com.ec","*.espn.com.uy","*.espn.com.pa","*.espn.co.cr","qa.abcnews.go.com","preview.abcnews.go ...
#   </script>
#   <script defer="" src="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/_manifest.js">
#   </script>
#   <script defer="" src="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/espn-en-9b286014.js">
#   </script>
#   <script defer="" src="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/espnfitt-07d5f3e3.js">
#   </script>
#   <script defer="" src="//cdn1.espn.net/fitt/2b164a97b4ee-release-12-06-2023.2.0.366/client/espnfitt/team.roster-1a93a713.js">
#   </script>
#  </body>
# </html>

# %%
#Insira a tag <li> e adicione sua classe
list_item = soup.find('table', attrs={'class': 'Table'})

# %%
name = list_item.text.strip()
print(name)
# Out:
# NamePOSAgeHTWTExpCollegeJeff Driskel19QB306' 4"235 lbs8Louisiana TechKyler Murray1QB265' 10"207 lbs5OklahomaClayton Tune15QB246' 3"220 lbsRHoustonMichael Carter22RB245' 8"201 lbs3North CarolinaCorey Clement23RB295' 10"220 lbs7WisconsinJames Conner6RB286' 1"233 lbs7PittsburghEmari Demercado31RB245' 9"215 lbsRTCUTony Jones Jr.37RB265' 11"224 lbs3Notre DameMarlon Mack32RB275' 11"210 lbs7South FloridaDaniel Arias81WR256' 3"216 lbsRColoradoAndre Baccellia82WR265' 10"175 lbs2WashingtonMarquise Brown2WR265' 9"180 lbs5OklahomaDan Chisena16WR266' 3"202 lbs3Penn StateKaden Davis17WR256' 1"190 lbs1--Greg Dortch83WR255' 7"175 lbs3Wake ForestRondale Moore4WR235' 7"180 lbs3PurdueZach Pascal0WR286' 2"215 lbs6Old DominionMichael Wilson14WR236' 2"213 lbsRStanfordElijah Higgins84TE236' 3"235 lbsRStanfordTrey McBride85TE246' 4"246 lbs2Colorado StateBernhard Seikovits80TE266' 5"262 lbs1--Geoff Swaim87TE306' 4"260 lbs9TexasBlake Whiteheart89TE236' 4"247 lbsRWake ForestTrystan Colon63C256' 3"313 lbs4MissouriKeith Ismael60C256' 3"309 lbs3San Diego StateDennis Daley71G276' 6"325 lbs5South CarolinaPat Elflein50G296' 2"303 lbs7Ohio StateHjalte Froholdt72G276' 5"310 lbs5ArkansasJon Gaines II59G246' 4"303 lbsRUCLAMarquis Hayes78G246' 5"318 lbs2OklahomaWill Hernandez76G286' 2"332 lbs6UTEPHayden Howerton75G246' 3"300 lbs1SMUJackson Barton66OT286' 7"302 lbs5UtahKelvin Beachum68OT346' 3"308 lbs12SMUD.J. Humphries74OT296' 5"307 lbs9FloridaParis Johnson Jr.70OT226' 6"313 lbsROhio StateCarter O'Donnell61OT246' 5"313 lbs2AlbertaElijah Wilkinson65OT286' 6"314 lbs7Massachusetts

# %%
#Insira a tag <li> e adicione sua classe
column = soup.find('colgroup', attrs={'class': 'Table__Colgroup'})

# %%
name1 = column.text.strip()
print(name1)
